# %%
import sys
sys.path.insert(0, "/Users/jakobwerkgarner/code/snow_to_swe-master")

import pandas as pd
from main import SnowToSwe

snow_to_swe = SnowToSwe()
swe_df = snow_to_swe.convert_csv("sample_hsdata.csv", path_to_output_csv="sample_out.csv", verbose=True)
display(swe_df)
